# %%
import pandas as pd

# %%
#reading csv file
df_exams = pd.read_csv('student_performance.csv')
df_exams.head()
# Out:
#    Student_ID  Gender  Age  Study_Hours_per_Week  Attendance_Percentage  \
# 0           1    Male   21                    14                     93
# 1           2  Female   21                    21                     94
# 2           3    Male   17                    24                     83
# 3           4    Male   19                    28                     52
# 4           5    Male   18                     9                     86
#
#    Previous_Grade  Assignments_Completed  Midterm_Score  Final_Score  \
# 0              93                      1             71           74
# 1              69                      1             95           79
# 2              73                      8             50           53
# 3              99                      4             59           74
# 4              98                      1             63           87
#
#   Overall_Result
# 0           Pass
# 1           Pass
# 2           Pass
# 3           Fail
# 4           Pass

# %% [markdown]
# ## 1 Selecting one Column

# %% [markdown]
# ### 1.1 Syntax 1

# %%
# selecting column with [] (preferred way to select a column)
df_exams['Gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3        Male
# 4        Male
#         ...
# 495      Male
# 496      Male
# 497    Female
# 498      Male
# 499    Female
# Name: Gender, Length: 500, dtype: object

# %%
# check out the data type of a column
type(df_exams['Gender'])
# Out:
# pandas.core.series.Series

# %%
# series : attributes and methods
(df_exams['Gender']).index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df_exams['Gender'].head()
# Out:
# 0      Male
# 1    Female
# 2      Male
# 3      Male
# 4      Male
# Name: Gender, dtype: object

# %% [markdown]
# ### 1.2 Syntax 2

# %%
#select a column with .
df_exams.Student_ID
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 495    496
# 496    497
# 497    498
# 498    499
# 499    500
# Name: Student_ID, Length: 500, dtype: int64

# %%
# select a column with . (pitfalls)
# if column name has space in it then it will cause error therefore [] is more preferred
