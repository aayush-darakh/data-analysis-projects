# %%
import pandas as pd

# %%
#reading the csv file
df_exams = pd.read_csv('student_performance.csv')
df_exams.head()
# Out:
#    Student_ID  Gender  Age  Study_Hours_per_Week  Attendance_Percentage  \
# 0           1    Male   21                    14                     93
# 1           2  Female   21                    21                     94
# 2           3    Male   17                    24                     83
# 3           4    Male   19                    28                     52
# 4           5    Male   18                     9                     86
#
#    Previous_Grade  Assignments_Completed  Midterm_Score  Final_Score  \
# 0              93                      1             71           74
# 1              69                      1             95           79
# 2              73                      8             50           53
# 3              99                      4             59           74
# 4              98                      1             63           87
#
#   Overall_Result
# 0           Pass
# 1           Pass
# 2           Pass
# 3           Fail
# 4           Pass

# %% [markdown]
# ## 1 Selecting two or more Columns

# %%
# select 2 columns using [[]]
df_exams[['Gender', 'Age']]
# Out:
#      Gender  Age
# 0      Male   21
# 1    Female   21
# 2      Male   17
# 3      Male   19
# 4      Male   18
# ..      ...  ...
# 495    Male   21
# 496    Male   21
# 497  Female   20
# 498    Male   18
# 499  Female   17
#
# [500 rows x 2 columns]

# %%
# check out the data type of the selection
type(df_exams[['Gender', 'Age']])
# [[]] represents dataframe while [] represents series(rows)
# Out:
# pandas.core.frame.DataFrame

# %%
# select two or more columns using [[]]
df_exams[['Attendance_Percentage',	'Assignments_Completed',	'Previous_Grade',	'Midterm_Score']]
# Out:
#      Attendance_Percentage  Assignments_Completed  Previous_Grade  \
# 0                       93                      1              93
# 1                       94                      1              69
# 2                       83                      8              73
# 3                       52                      4              99
# 4                       86                      1              98
# ..                     ...                    ...             ...
# 495                     73                      0              83
# 496                     69                     10              63
# 497                     86                      6              85
# 498                     53                      5              82
# 499                     77                      1              72
#
#      Midterm_Score
# 0               71
# 1               95
# 2               50
# 3               59
# 4               63
# ..             ...
# 495             40
# ...

# %%
# we can't use 2 or more columns using '.'
