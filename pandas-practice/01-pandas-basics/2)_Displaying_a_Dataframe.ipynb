# %%
import pandas as pd

# %%
# reading a csv file
df_exams =  pd.read_csv('student_performance.csv')

# %%
df_exams
# Out:
#      Student_ID  Gender  Age  Study_Hours_per_Week  Attendance_Percentage  \
# 0             1    Male   21                    14                     93
# 1             2  Female   21                    21                     94
# 2             3    Male   17                    24                     83
# 3             4    Male   19                    28                     52
# 4             5    Male   18                     9                     86
# ..          ...     ...  ...                   ...                    ...
# 495         496    Male   21                    21                     73
# 496         497    Male   21                    18                     69
# 497         498  Female   20                    35                     86
# 498         499    Male   18                    28                     53
# 499         500  Female   17                    39                     77
#
#      Previous_Grade  Assignments_Completed  Midterm_Score  Final_Score  \
# ...

# %%
#displaying first five rows
df_exams.head()
# Out:
#    Student_ID  Gender  Age  Study_Hours_per_Week  Attendance_Percentage  \
# 0           1    Male   21                    14                     93
# 1           2  Female   21                    21                     94
# 2           3    Male   17                    24                     83
# 3           4    Male   19                    28                     52
# 4           5    Male   18                     9                     86
#
#    Previous_Grade  Assignments_Completed  Midterm_Score  Final_Score  \
# 0              93                      1             71           74
# 1              69                      1             95           79
# 2              73                      8             50           53
# 3              99                      4             59           74
# 4              98                      1             63           87
#
#   Overall_Result
# 0           Pass
# 1           Pass
# 2           Pass
# 3           Fail
# 4           Pass

# %%
#displaying last five rows
df_exams.tail()
# Out:
#      Student_ID  Gender  Age  Study_Hours_per_Week  Attendance_Percentage  \
# 495         496    Male   21                    21                     73
# 496         497    Male   21                    18                     69
# 497         498  Female   20                    35                     86
# 498         499    Male   18                    28                     53
# 499         500  Female   17                    39                     77
#
#      Previous_Grade  Assignments_Completed  Midterm_Score  Final_Score  \
# 495              83                      0             40           77
# 496              63                     10             96           55
# 497              85                      6             68           41
# 498              82                      5             84           79
# 499              72                      1             88           56
#
#     Overall_Result
# 495           Pass
# 496           Pass
# 497           Fail
# ...

# %%
#display first n rows
df_exams.head(15)
# Out:
#     Student_ID  Gender  Age  Study_Hours_per_Week  Attendance_Percentage  \
# 0            1    Male   21                    14                     93
# 1            2  Female   21                    21                     94
# 2            3    Male   17                    24                     83
# 3            4    Male   19                    28                     52
# 4            5    Male   18                     9                     86
# 5            6  Female   17                    38                     92
# 6            7    Male   18                    10                     89
# 7            8    Male   22                     6                     75
# 8            9    Male   18                    17                     72
# 9           10  Female   19                    15                     93
# 10          11    Male   22                    27                     88
# 11          12    Male   18                    20                     64
# ...

# %%
#display last n rows
df_exams.tail(15)
# Out:
#      Student_ID  Gender  Age  Study_Hours_per_Week  Attendance_Percentage  \
# 485         486  Female   18                    11                     84
# 486         487    Male   20                    13                     78
# 487         488  Female   17                    12                     64
# 488         489    Male   22                    27                     82
# 489         490    Male   17                    33                     56
# 490         491  Female   20                    22                     61
# 491         492    Male   22                    35                     98
# 492         493    Male   18                    34                     79
# 493         494  Female   19                    39                     70
# 494         495    Male   17                    22                     80
# 495         496    Male   21                    21                     73
# 496         497    Male   21                    18                     69
# ...

# %%
# getting access to shape attribute of dataframe ie number of rows and columns
df_exams.shape
# Out:
# (500, 10)

# %%
# displaying n number of rows
pd.set_option("display.max_rows", 500) #if df has more than n(500) don't print everything
df_exams
# Out:
#      Student_ID  Gender  Age  Study_Hours_per_Week  Attendance_Percentage  \
# 0             1    Male   21                    14                     93
# 1             2  Female   21                    21                     94
# 2             3    Male   17                    24                     83
# 3             4    Male   19                    28                     52
# 4             5    Male   18                     9                     86
# 5             6  Female   17                    38                     92
# 6             7    Male   18                    10                     89
# 7             8    Male   22                     6                     75
# 8             9    Male   18                    17                     72
# 9            10  Female   19                    15                     93
# 10           11    Male   22                    27                     88
# 11           12    Male   18                    20                     64
# ...
